# %% [markdown]
# <div style="background-color:#f2f2f2; border-left: 8px solid #2e8b57; padding: 20px; border-radius: 10px; font-family: Arial, sans-serif;">
#
# <center>
#
# <h1 style="color:#2e8b57;">Tarea 1: Cómputo científico con Python</h1>
# <h2 style="color:#2e8b57;">Instituto Mexicano del Petróleo</h2>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dra. Gabriela Berenice Díaz Cortés</strong><br>
# <em>gbdiaz@imp.mx</em>
# </p>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dr. Luis Antonio López Peña</strong><br>
# <em>llopezp@imp.mx</em>
# </p>
#
# <p style="font-size:15px; color:#555;">
# Dirección de Investigación <br>
# Gerencia de Investigación en Explotación
# </p>
#
# <p style="font-size:15px; color:#444; margin-top: 20px;">
# <strong>Fecha de asignación:</strong> 4 de junio de 2026<br>
# <strong>Fecha de entrega:</strong> 9 de junio de 2026
# </p>
#
# </center>
#
# </div>

# %% [markdown]
# Ejercicio 1.

# %%
Nombre = input("Escribe tu nombre: ")
# Out:
# Escribe tu nombre:  Nadia Karina Gonzalez Andrade

# %% [markdown]
# Ejercicio 2. Diccionario de usuario
# 1. Pide al usuario que ingrese:
#     - Nombre
#     - Edad
#     - Ciudad
# 2. Guarda estos datos en un diccionario.
# 3. Imprime un mensaje como:
#    `"María tiene 30 años y vive en Guadalajara"`

# %%
# Respuesta
Nombre_user=input("Ingresa tu nombre: ")
Edad_user=input("Ingresa tu edad: ")
Ciudad_user=input("Ingresa la ciudad donde vives: ")
user_data={"Nombre":Nombre_user,"Edad":Edad_user,"Ciudad":Ciudad_user}
print(f"{Nombre_user} tiene {Edad_user} años y vive en {Ciudad_user}")
# Out:
# Ingresa tu nombre:  Nadia
# Ingresa tu edad:  36
# Ingresa la ciudad donde vives:  mexico
# Nadia tiene 36 años y vive en mexico

# %% [markdown]
# Ejercicio 3. Conversor de Temperaturas
#
# 1. Pide al usuario que ingrese una temperatura en °C.
# 2. Convierte esa temperatura a °F usando la fórmula:
#    $$ F = C \times \frac{9}{5} + 32 $$
# 3. Muestra el resultado con un mensaje claro redondeando a 2 decimales.

# %%
# Respuesta
temp_C=int(input("Ingresa una temperatura (°C): "))
temp_F=temp_C*(9/5)+32
print(f"La temperatura {temp_C} °C es igual a {temp_F} °F")
# Out:
# Ingresa una temperatura (°C):  20
# La temperatura 20 °C es igual a 68.0 °F

# %% [markdown]
# Ejercicio 4. Escribe un programa que pida números al usuario y los vaya sumando. El ciclo termina cuando el usuario ingresa un `0` o cuando la suma es mayor que 50. Usa `while` y `break`.

# %%
# Respuesta
suma=0
while suma<=50:
    x=int(input("Ingresa un numero: "))
    if x==0:
        print("El ciclo ha terminado")
        break
    suma+=x
if suma>50:
        print("El ciclo ha terminado")
print("La suma total de los numeros es: ", suma)
# Out:
# Ingresa un numero:  3
# Ingresa un numero:  2
# Ingresa un numero:  3
# Ingresa un numero:  10
# Ingresa un numero:  40
# El ciclo ha terminado
# La suma total de los numeros es:  58

# %% [markdown]
# Ejercicio 5. Usa un ciclo for para guardar en una lista los números del 1 al 10, pero salta los números pares usando continue.

# %%
# Respuesta
nums=[]
for n in range(1,11):
    if n%2==0:
        continue
    nums.append(n)
print(nums)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# Ejercicio 6. Escriba una función que tenga como argumento el lado de un cuadrado y regrese su área.

# %%
# Respuesta
def area(l):
    area=l*l
    return area

# %%
lado=int(input("Ingresa el lado (cm) de un cuadrado: "))
area_c=area(lado)
print(f"El area del cuadrado que mide {lado} cm por lado es de {area_c} cm2")
# Out:
# Ingresa el lado (cm) de un cuadrado:  6
# El area del cuadrado que mide 6 cm por lado es de 36 cm2

# %% [markdown]
# Ejercicio 7. Escribe una función *my_max(x)* que de como salida el valor máximo (más grande) de una lista *x*. No use la función de Python *max*.
#
# Encuentra el máximo de la siguiente lista
#
# x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]

# %%
# Respuesta
def mymax(x):
    mayor=x[0]
    for numero in x:
        if numero>mayor:
            mayor=numero
    return(mayor)

# %%
x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]
mymax(x)
# Out:
# 893

# %% [markdown]
# Ejercicio 8. Pide al usuario una contraseña. Permite hasta 3 intentos, y termina el ciclo si la acierta. Usa while, break y un contador.

# %%
# Respuesta
max_intentos=3
contador=0
password="IMP200"
while contador<max_intentos:
    user=input("Ingresa una contraseña: ")
    contador+=1
    if user==password:
        print("La contraseña es correcta. Bienvenido")
        break
    else:
        print("Contraseña incorrecta. Intenta de nuevo")
if contador==max_intentos and user!=password:
    print("Se agotaron los intentos")
# Out:
# Ingresa una contraseña:  sd
# Contraseña incorrecta. Intenta de nuevo
# Ingresa una contraseña:  IMP200
# La contraseña es correcta. Bienvenido

# %% [markdown]
# ##### ========================================================================================
# ### Evaluación
# 1. Ok. 1 punto
# 2. Ok. 1 punto
# 3. Ok: 1 punto
# 4. Ok. 1 punto
# 5. Ok. 1 punto
# 6. Ok. 1 punto
# 7. Ok. 1 punto
#
# Calificación final: 7 puntos
# ##### ========================================================================================

# %%
aciertos = [1,1,1,1,1,1,1]
print("Calificación: ",sum(aciertos)*10/ len(aciertos))
# Out:
# Calificación:  10.0
