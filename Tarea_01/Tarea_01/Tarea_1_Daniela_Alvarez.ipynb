# %% [markdown]
# <div style="background-color:#f2f2f2; border-left: 8px solid #2e8b57; padding: 20px; border-radius: 10px; font-family: Arial, sans-serif;">
#
# <center>
#
# <h1 style="color:#2e8b57;">Tarea 1: Cómputo científico con Python</h1>
# <h2 style="color:#2e8b57;">Instituto Mexicano del Petróleo</h2>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dra. Gabriela Berenice Díaz Cortés</strong><br>
# <em>gbdiaz@imp.mx</em>
# </p>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dr. Luis Antonio López Peña</strong><br>
# <em>llopezp@imp.mx</em>
# </p>
#
# <p style="font-size:15px; color:#555;">
# Dirección de Investigación <br>
# Gerencia de Investigación en Explotación
# </p>
#
# <p style="font-size:15px; color:#444; margin-top: 20px;">
# <strong>Fecha de asignación:</strong> 4 de junio de 2026<br>
# <strong>Fecha de entrega:</strong> 9 de junio de 2026
# </p>
#
# </center>
#
# </div>

# %% [markdown]
# Ejercicio 1.

# %%
Nombre = input("Escribe tu nombre:")
# Out:
# Escribe tu nombre: Daniela

# %% [markdown]
# Ejercicio 2. Diccionario de usuario
# 1. Pide al usuario que ingrese:
#     - Nombre
#     - Edad
#     - Ciudad
# 2. Guarda estos datos en un diccionario.
# 3. Imprime un mensaje como:
#    `"María tiene 30 años y vive en Guadalajara"`

# %%
Nombre=str(input('Ingresar su nombre completo:  '))
Edad=int(input('Puede ingresar su edad: '))
Ciudad=str(input('Puede proporcionarnos su ciudad de residencia: '))
Diccionario={'Nombre':Nombre,'Edad': Edad,'Ciudad': Ciudad}
print(f'{Nombre} tiene{Edad} años y vive en {Ciudad}')
# Out:
# Ingresar su nombre completo:   A
# Puede ingresar su edad:  89
# Puede proporcionarnos su ciudad de residencia:  city
# A tiene89 años y vive en city

# %% [markdown]
# Ejercicio 3. Conversor de Temperaturas
#
# 1. Pide al usuario que ingrese una temperatura en °C.
# 2. Convierte esa temperatura a °F usando la fórmula:
#    $$ F = C \times \frac{9}{5} + 32 $$
# 3. Muestra el resultado con un mensaje claro redondeando a 2 decimales.

# %%
# Respuesta
TemperaturaC=float(input('Ingresar una temperatura en  °C: '))
F= ((TemperaturaC*(9/5))+32)
print("{0:.2f}".format(F))
# Out:
# Ingresar una temperatura en  °C:  67
# 152.60

# %% [markdown]
# Ejercicio 4. Escribe un programa que pida números al usuario y los vaya sumando. El ciclo termina cuando el usuario ingresa un `0` o cuando la suma es mayor que 50. Usa `while` y `break`.

# %%
# Respuesta
suma=0
numero=float(input('Ingresa un numero: ' ))
while numero !=0:
  suma = suma + numero
  print('La suma es:', suma)
  if suma>=50:
   print('Acabas de generar una suma mayor a 50, el programa procedera a cerrarse')
   break
  numero=float(input('Ingresa un numero: ' ))
else:
  numero==0
  print('Acabas de ingresar el valor 0, el programa procedera a cerrarse')
# Out:
# Ingresa un numero:  2
# La suma es: 2.0
# Ingresa un numero:  46
# La suma es: 48.0
# Ingresa un numero:  3
# La suma es: 51.0
# Acabas de generar una suma mayor a 50, el programa procedera a cerrarse

# %% [markdown]
# Ejercicio 5. Usa un ciclo for para guardar en una lista los números del 1 al 10, pero salta los números pares usando continue.

# %%
# Respuesta
nMax=11
a=[]
for i in range (1,nMax):
    if i %2==0:
        continue
    a.append(i)
print(a)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# Ejercicio 6. Escriba una función que tenga como argumento el lado de un cuadrado y regrese su área.

# %%
# Respuesta
def area(l):
  resultado=l*l
  print('El area de tu cuadrado es de:',resultado)

# %%
l=float(input('Ingrese el valor del lado de su cuadrado: '))
area(l)
# Out:
# Ingrese el valor del lado de su cuadrado:  5
# El area de tu cuadrado es de: 25.0

# %% [markdown]
# Ejercicio 7. Escribe una función *my_max(x)* que de como salida el valor máximo (más grande) de una lista *x*. No use la función de Python *max*.
#
# Encuentra el máximo de la siguiente lista
#
# x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]

# %%
# Respuesta
def my_max(x):
 y=x[0]
 for i in x:
  if i>y:
    y=i
 return y

# %%
x = [10, 56, 258, 16, 24, 18, 45456456, 1, 71, 10000000000000000, 82]
print(my_max(x))
# Out:
# 10000000000000000

# %% [markdown]
# Ejercicio 8. Pide al usuario una contraseña. Permite hasta 3 intentos, y termina el ciclo si la acierta. Usa while, break y un contador.

# %%
# Respuesta
Contraseña='Daniela'
Intentos=0
while Intentos<3:
  Usuario=input('Ingresa la contraseña correcta: ')
  Intentos+=1
  if Usuario==Contraseña:
    print('Acceso concedido')
    break
  else:
    intentosrestantes=3-Intentos
    print('Intentos restantes:', intentosrestantes)
    print('Intenta otra vez')
else:
  print('Cuenta bloqueada')
# Out:
# Ingresa la contraseña correcta:  a
# Intentos restantes: 2
# Intenta otra vez
# Ingresa la contraseña correcta:  f
# Intentos restantes: 1
# Intenta otra vez
# Ingresa la contraseña correcta:  s
# Intentos restantes: 0
# Intenta otra vez
# Cuenta bloqueada

# %% [markdown]
# ##### ========================================================================================
# ### Evaluación
# 1. Ok. 1 punto
# 2. Ok. 1 punto
# 3. Ok: 1 punto
# 4. Ok. 1 puntos
# 5. Ok. 1 puntos
# 6. Ok. 1 puntos
# 7. Ok. 1 puntos
#
# Calificación final: 7 puntos
# ##### ========================================================================================

# %%
aciertos = [1,1,1,1,1,1,1]
print("Calificación: ",sum(aciertos)*10/ len(aciertos))
# Out:
# Calificación:  10.0
