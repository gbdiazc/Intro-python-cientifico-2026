# %% [markdown]
# <div style="background-color:#f2f2f2; border-left: 8px solid #2e8b57; padding: 20px; border-radius: 10px; font-family: Arial, sans-serif;">
#
# <center>
#
# <h1 style="color:#2e8b57;">Tarea 1: Cómputo científico con Python</h1>
# <h2 style="color:#2e8b57;">Instituto Mexicano del Petróleo</h2>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dra. Gabriela Berenice Díaz Cortés</strong><br>
# <em>gbdiaz@imp.mx</em>
# </p>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dr. Luis Antonio López Peña</strong><br>
# <em>llopezp@imp.mx</em>
# </p>
#
# <p style="font-size:15px; color:#555;">
# Dirección de Investigación <br>
# Gerencia de Investigación en Explotación
# </p>
#
# <p style="font-size:15px; color:#444; margin-top: 20px;">
# <strong>Fecha de asignación:</strong> 4 de junio de 2026<br>
# <strong>Fecha de entrega:</strong> 9 de junio de 2026
# </p>
#
# </center>
#
# </div>

# %% [markdown]
# Alumno: Josue Andrade Hdez

# %% [markdown]
# Ejercicio 1.

# %%
Nombre = input("Escribe tu nombre:")
# Out:
# Escribe tu nombre:Josue Andrade

# %% [markdown]
# Ejercicio 2. Diccionario de usuario
# 1. Pide al usuario que ingrese:
#     - Nombre
#     - Edad
#     - Ciudad
# 2. Guarda estos datos en un diccionario.
# 3. Imprime un mensaje como:
#    `"María tiene 30 años y vive en Guadalajara"`

# %%
# Respuesta
# Ejercicio 2. Diccionario de usuario

# 1. Pedir al usuario que ingrese los datos
nombre = input("Ingresa tu nombre: ")
edad = input("Ingresa tu edad: ")
ciudad = input("Ingresa tu ciudad: ")

# 2. Guardar los datos en un diccionario
usuario = {
    "nombre": nombre,
    "edad": edad,
    "ciudad": ciudad
}

# 3. Imprimir el mensaje formateado
print(f"{usuario['nombre']} tiene {usuario['edad']} años y vive en {usuario['ciudad']}")
# Out:
# Ingresa tu nombre:  A
# Ingresa tu edad:  67
# Ingresa tu ciudad:  city
# A tiene 67 años y vive en city

# %% [markdown]
# Ejercicio 3. Conversor de Temperaturas
#
# 1. Pide al usuario que ingrese una temperatura en °C.
# 2. Convierte esa temperatura a °F usando la fórmula:
#    $$ F = C \times \frac{9}{5} + 32 $$
# 3. Muestra el resultado con un mensaje claro redondeando a 2 decimales.

# %%
# Respuesta
celsius = float(input("Ingresa la temperatura en °C: "))
fahrenheit = celsius * 9/5 + 32
print(f"{celsius}°C equivalen a {round(fahrenheit, 2)}°F")
# Out:
# Ingresa la temperatura en °C:  34
# 34.0°C equivalen a 93.2°F

# %% [markdown]
# Ejercicio 4. Escribe un programa que pida números al usuario y los vaya sumando. El ciclo termina cuando el usuario ingresa un `0` o cuando la suma es mayor que 50. Usa `while` y `break`.

# %%
# Respuesta
suma = 0
while True:
    numero = int(input("Ingresa un número: "))
    suma += numero

    if numero == 0 or suma > 50:
        break

print(f"La suma final es: {suma}")
# Out:
# Ingresa un número:  34
# Ingresa un número:  23
# La suma final es: 57

# %% [markdown]
# Ejercicio 5. Usa un ciclo for para guardar en una lista los números del 1 al 10, pero salta los números pares usando continue.

# %%
# Respuesta
numeros = []

for i in range(1, 11):  # del 1 al 10
    if i % 2 == 0:      # si es par
        continue        # saltar este número
    numeros.append(i)   # guardar solo los impares

print("Lista final:", numeros)
# Out:
# Lista final: [1, 3, 5, 7, 9]

# %% [markdown]
# Ejercicio 6. Escriba una función que tenga como argumento el lado de un cuadrado y regrese su área.

# %%
# Respuesta
def area_cuadrado(lado):
    return lado * lado

# Ejemplo de uso
lado = float(input("Ingresa el lado del cuadrado: "))
print(f"El área del cuadrado es: {area_cuadrado(lado)}")
# Out:
# Ingresa el lado del cuadrado:  5
# El área del cuadrado es: 25.0

# %% [markdown]
# Ejercicio 7. Escribe una función *my_max(x)* que de como salida el valor máximo (más grande) de una lista *x*. No use la función de Python *max*.
#
# Encuentra el máximo de la siguiente lista
#
# x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]

# %%
# Respuesta
def my_max(x):
    # Tomamos el primer elemento como máximo inicial
    maximo = x[0]

    # Recorremos la lista comparando cada elemento
    for numero in x:
        if numero > maximo:
            maximo = numero

    return maximo

# Lista de ejemplo
x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]

# Usamos la función
resultado = my_max(x)
print("El valor máximo es:", resultado)
# Out:
# El valor máximo es: 893

# %% [markdown]
# Ejercicio 8. Pide al usuario una contraseña. Permite hasta 3 intentos, y termina el ciclo si la acierta. Usa while, break y un contador.

# %%
# Respuesta
# Definimos la contraseña correcta
password_correcta = "python123"

# Inicializamos el contador de intentos
intentos = 0

while intentos < 3:
    password = input("Ingresa la contraseña: ")
    intentos += 1

    if password == password_correcta:
        print("¡Acceso concedido!")
        break
    else:
        print("Contraseña incorrecta.")

        if intentos == 3:
            print("Has agotado los 3 intentos. Acceso denegado.")
# Out:
# Ingresa la contraseña:  34
# Contraseña incorrecta.
# Ingresa la contraseña:  23
# Contraseña incorrecta.
# Ingresa la contraseña:  4
# Contraseña incorrecta.
# Has agotado los 3 intentos. Acceso denegado.

# %% [markdown]
# ##### ========================================================================================
# ### Evaluación
# 1. Ok. 1 punto
# 2. Ok. 1 punto
# 3. Ok: 1 punto
# 4. Ok. 1 punto
# 5. Ok. 1 punto
# 6. Ok. 1 punto
# 7. Ok. 1 punto
#
# Calificación final: 7 puntos
# ##### ========================================================================================

# %%
aciertos = [1,1,1,1,1,1,1]
print("Calificación: ",sum(aciertos)*10/ len(aciertos))
# Out:
# Calificación:  10.0
