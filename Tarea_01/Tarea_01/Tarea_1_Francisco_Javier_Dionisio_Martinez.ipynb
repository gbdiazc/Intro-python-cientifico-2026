# %% [markdown]
# <div style="background-color:#f2f2f2; border-left: 8px solid #2e8b57; padding: 20px; border-radius: 10px; font-family: Arial, sans-serif;">
#
# <center>
#
# <h1 style="color:#2e8b57;">Tarea 1: Cómputo científico con Python</h1>
# <h2 style="color:#2e8b57;">Instituto Mexicano del Petróleo</h2>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dra. Gabriela Berenice Díaz Cortés</strong><br>
# <em>gbdiaz@imp.mx</em>
# </p>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dr. Luis Antonio López Peña</strong><br>
# <em>llopezp@imp.mx</em>
# </p>
#
# <p style="font-size:15px; color:#555;">
# Dirección de Investigación <br>
# Gerencia de Investigación en Explotación
# </p>
#
# <p style="font-size:15px; color:#444; margin-top: 20px;">
# <strong>Fecha de asignación:</strong> 4 de junio de 2026<br>
# <strong>Fecha de entrega:</strong> 9 de junio de 2026
# </p>
#
# </center>
#
# </div>

# %% [markdown]
# Ejercicio 1.

# %%
Nombre = input("Escribe tu nombre:")
# Out:
# Escribe tu nombre:Francisco Javier Dionisio Martínez

# %% [markdown]
# Ejercicio 2. Diccionario de usuario
# 1. Pide al usuario que ingrese:
#     - Nombre
#     - Edad
#     - Ciudad
# 2. Guarda estos datos en un diccionario.
# 3. Imprime un mensaje como:
#    `"María tiene 30 años y vive en Guadalajara"`

# %%
# Respuesta
name=str(input("Ingrese su nombre: "))
age=str(input("Ingrese su edad: "))
city=str(input("Ingrese su ciudad: "))

my_data= {"nombre":name,
          "edad":age,
          "ciudad":city}
print(my_data["nombre"], "tiene", my_data["edad"], "años y vive en", my_data["ciudad"])
# Out:
# Ingrese su nombre:  A
# Ingrese su edad:  56
# Ingrese su ciudad:  city
# A tiene 56 años y vive en city

# %% [markdown]
# Ejercicio 3. Conversor de Temperaturas
#
# 1. Pide al usuario que ingrese una temperatura en °C.
# 2. Convierte esa temperatura a °F usando la fórmula:
#    $$ F = C \times \frac{9}{5} + 32 $$
# 3. Muestra el resultado con un mensaje claro redondeando a 2 decimales.

# %%
# Respuesta
tempc=float(input("Ingrese la Temperatura en °C: "))
tempf=tempc*(9/5)+32
print("La Temperatura en grados °F es: %.2f"%tempf)
# Out:
# Ingrese la Temperatura en °C:  34
# La Temperatura en grados °F es: 93.20

# %% [markdown]
# Ejercicio 4. Escribe un programa que pida números al usuario y los vaya sumando. El ciclo termina cuando el usuario ingresa un `0` o cuando la suma es mayor que 50. Usa `while` y `break`.

# %%
# Respuesta
num = 0
while num <= 50:
  i = int(input("Ingresa un número "))
  num = num + i

  if i == 0:
    print ("Introduce otro número diferente a cero")
    break

print ("La suma de los números es", num)
# Out:
# Ingresa un número  34
# Ingresa un número  2
# Ingresa un número  50
# La suma de los números es 86

# %% [markdown]
# Ejercicio 5. Usa un ciclo for para guardar en una lista los números del 1 al 10, pero salta los números pares usando continue.

# %%
# Respuesta
for a in range(1, 10):
  if a % 2 == 0:
    continue

  print(a)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# Ejercicio 6. Escriba una función que tenga como argumento el lado de un cuadrado y regrese su área.

# %%
# Respuesta
def area(a):
  sqr=a*a
  return sqr

# %%
a=float(input("Ingrese el valor del lado del cuadrado: "))
area_sqr=area(a)
print("El área del cuadrado es", area_sqr)
# Out:
# Ingrese el valor del lado del cuadrado:  4
# El área del cuadrado es 16.0

# %% [markdown]
# Ejercicio 7. Escribe una función *my_max(x)* que de como salida el valor máximo (más grande) de una lista *x*. No use la función de Python *max*.
#
# Encuentra el máximo de la siguiente lista
#
# x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]

# %%
# Respuesta
x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]
def my_max (x):
  max = 0
  for i in range (0,len(x)):
    if max < x [i]:
      max = x [i]
    else:
      continue
  print ("El número máximo de la lista es",max)
my_max(x)
# Out:
# El número máximo de la lista es 893

# %% [markdown]
# Ejercicio 8. Pide al usuario una contraseña. Permite hasta 3 intentos, y termina el ciclo si la acierta. Usa while, break y un contador.

# %%
# Respuesta
passw=input("Ingrese su contraseña: ")
cont = 0

while (cont < 3):
  verif = input("Ingrese de nuevo su contraseña: ")
  cont += 1

  if (passw == verif):
    print ("La contraseña es correcta")
    break

  else:
    print ("Contraseña incorrecta")

if passw != verif:
  print ("El dispositivo se ha bloqueado")
# Out:
# Ingrese su contraseña:  21
# Ingrese de nuevo su contraseña:  45
# Contraseña incorrecta
# Ingrese de nuevo su contraseña:  23
# Contraseña incorrecta
# Ingrese de nuevo su contraseña:  56
# Contraseña incorrecta
# El dispositivo se ha bloqueado

# %% [markdown]
# ##### ========================================================================================
# ### Evaluación
# 1. Ok. 1 punto
# 2. Ok. 1 punto
# 3. Ok: 1 punto
# 4. Ok. 1. Casi debía entregar una lista. 1 punto
# 5. Ok. 1 punto
# 6. Ok. 1 punto
# 7. Ok. 1 punto
#
# Calificación final: 7 puntos
# ##### ========================================================================================

# %%
aciertos = [1,1,1,1,1,1,1]
print("Calificación: ",sum(aciertos)*10/ len(aciertos))
# Out:
# Calificación:  10.0
