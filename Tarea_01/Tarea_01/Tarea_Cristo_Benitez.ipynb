# %% [markdown]
# <div style="background-color:#f2f2f2; border-left: 8px solid #2e8b57; padding: 20px; border-radius: 10px; font-family: Arial, sans-serif;">
#
# <center>
#
# <h1 style="color:#2e8b57;">Tarea 1: Cómputo científico con Python</h1>
# <h2 style="color:#2e8b57;">Instituto Mexicano del Petróleo</h2>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dra. Gabriela Berenice Díaz Cortés</strong><br>
# <em>gbdiaz@imp.mx</em>
# </p>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dr. Luis Antonio López Peña</strong><br>
# <em>llopezp@imp.mx</em>
# </p>
#
# <p style="font-size:15px; color:#555;">
# Dirección de Investigación <br>
# Gerencia de Investigación en Explotación
# </p>
#
# <p style="font-size:15px; color:#444; margin-top: 20px;">
# <strong>Fecha de asignación:</strong> 4 de junio de 2026<br>
# <strong>Fecha de entrega:</strong> 9 de junio de 2026
# </p>
#
# </center>
#
# </div>

# %% [markdown]
# Ejercicio 1.

# %%
Nombre = input("Escribe tu nombre:")
#Nombre = 'Benitez Mesino Cristo Gerardo'
# Out:
# Escribe tu nombre:Benitez Mesino Cristo Gerardo

# %% [markdown]
# Ejercicio 2. Diccionario de usuario
# 1. Pide al usuario que ingrese:
#     - Nombre
#     - Edad
#     - Ciudad
# 2. Guarda estos datos en un diccionario.
# 3. Imprime un mensaje como:
#    `"María tiene 30 años y vive en Guadalajara"`

# %%
# Respuesta
nombre = input('Escriba su primer nombre: ')
edad = int(input('Escriba su edad actual: '))
ciudad = input('Escriba la ciudad donde vive: ')
datos = {'name': nombre,
         'age' : edad,
         'city': ciudad}
print(f'{datos['name']} tiene {datos['age']} años y actualmente vive en {datos['city']}')
# Out:
# Escriba su primer nombre:  NAme
# Escriba su edad actual:  23
# Escriba la ciudad donde vive:  None
# NAme tiene 23 años y actualmente vive en None

# %% [markdown]
# Ejercicio 3. Conversor de Temperaturas
#
# 1. Pide al usuario que ingrese una temperatura en °C.
# 2. Convierte esa temperatura a °F usando la fórmula:
#    $$ F = C \times \frac{9}{5} + 32 $$
# 3. Muestra el resultado con un mensaje claro redondeando a 2 decimales.

# %%
# Respuesta
tempC = int(input('Ingrese su temperatura en °C: '))
tempF = tempC * (9 / 5) + 32
print(f'{tempC} °C equivalen a {tempF:.2f}')
# Out:
# Ingrese su temperatura en °C:  23
# 23 °C equivalen a 73.40

# %% [markdown]
# Ejercicio 4. Escribe un programa que pida números al usuario y los vaya sumando. El ciclo termina cuando el usuario ingresa un `0` o cuando la suma es mayor que 50. Usa `while` y `break`.

# %%
# Respuesta
suma = 0
while suma < 50:
  n = int(input('Inserte un número que se sumará: '))
  if n == 0:
    break
  suma += n
  print(f'La suma actual es {suma}')
# Out:
# Inserte un número que se sumará:  23
# La suma actual es 23
# Inserte un número que se sumará:  12
# La suma actual es 35
# Inserte un número que se sumará:  4
# La suma actual es 39
# Inserte un número que se sumará:  34
# La suma actual es 73

# %% [markdown]
# Ejercicio 5. Usa un ciclo for para guardar en una lista los números del 1 al 10, pero salta los números pares usando continue.

# %%
# Respuesta
lista = []
for i in range(1,11):
  if i % 2 == 0:
    continue
  lista.append(i)
print(lista)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# Ejercicio 6. Escriba una función que tenga como argumento el lado de un cuadrado y regrese su área.

# %%
# Respuesta
def area_cuadrado(lado):
  area = lado ** 2
  return area

l = int(input('Inserte la medida en cm de un cuadrado: '))
area = area_cuadrado(l)
print(f'El area del cuadrado, cuyo lado mide {l} cm es {area} cm2.')
# Out:
# Inserte la medida en cm de un cuadrado:  3
# El area del cuadrado, cuyo lado mide 3 cm es 9 cm2.

# %% [markdown]
# Ejercicio 7. Escribe una función *my_max(x)* que de como salida el valor máximo (más grande) de una lista *x*. No use la función de Python *max*.
#
# Encuentra el máximo de la siguiente lista
#
# x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]

# %%
# Respuesta
def my_max(lista):
  lange = len(lista)
  i = 0
  j = 0
  mayor = 0
  for i in range(lange):
    for j in range(lange):
      if x[i] >= x[j]:
        mayor2 = x[i]
      else:
        mayor2 = x[j]
      if mayor2 >= mayor:
        mayor = mayor2
  return mayor

x = [10, 56, 258, 16, 24, 18, 265, 893, 52, 39, 82]

max = my_max(x)
print(f'El valor máximo de la matriz es {max}')
# Out:
# El valor máximo de la matriz es 893

# %% [markdown]
# Ejercicio 8. Pide al usuario una contraseña. Permite hasta 3 intentos, y termina el ciclo si la acierta. Usa while, break y un contador.

# %% [markdown]
# # Respuesta
# contrachida = 'holatengo24'
# contra = 'Contra'
# print('Introduzca su contraeña: ')
# intento = 0
# while contra != contrachida:
#   contra = input('Ingrese su contraseña')
#   intento += 1
#   if intento == 3:
#     break

# %%
# Respuesta
contrachida = 'holatengo24'
contra = 'Contra'
print('Solamente tendrá tres intentos para acertar la contraseña')
intento = 0
while contra != contrachida:
  contra = input('Ingrese su contraseña: ')
  intento += 1
  if intento == 3:
    break
if contra != contrachida:
  print('Contraseña incorrecta y número de intentos superados. ;)')
else:
  print('Contraseña conrrecta')
# Out:
# Solamente tendrá tres intentos para acertar la contraseña
# Ingrese su contraseña:  sdf
# Ingrese su contraseña:  sdf
# Ingrese su contraseña:  holatengo24
# Contraseña conrrecta

# %% [markdown]
# ##### ========================================================================================
# ### Evaluación
# 1. Ok. 1 punto
# 2. Ok. 1 punto
# 3. Ok: 1 punto
# 4. Ok. 1 punto
# 5. Ok. 1 punto
# 6. Ok. 1 punto
# 7. Ok. 1 punto
#
# Calificación final: 7 puntos
# ##### ========================================================================================

# %%
aciertos = [1,1,1,1,1,1,1]
print("Calificación: ",sum(aciertos)*10/ len(aciertos))
# Out:
# Calificación:  10.0
