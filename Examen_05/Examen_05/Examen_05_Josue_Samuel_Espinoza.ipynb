# %% [markdown]
# <div style="background-color:#f2f2f2; border-left: 8px solid #2e8b57; padding: 20px; border-radius: 10px; font-family: Arial, sans-serif;">
#
# <center>
#
# <h1 style="color:#2e8b57;">Exámen 5: Cómputo científico con Python</h1>
# <h2 style="color:#2e8b57;">Instituto Mexicano del Petróleo</h2>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dra. Gabriela Berenice Díaz Cortés</strong><br>
# <em>gbdiaz@imp.mx</em>
# </p>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dr. Luis Antonio López Peña</strong><br>
# <em>llopezp@imp.mx</em>
# </p>
#
# <p style="font-size:15px; color:#555;">
# Dirección de Investigación <br>
# Gerencia de Investigación en Explotación
# </p>
#
# <p style="font-size:15px; color:#444; margin-top: 20px;">
# <strong>Fecha de asignación:</strong> 4 de junio de 2026<br>
# <strong>Fecha de entrega:</strong> 9 de junio de 2026
# </p>
#
# </center>
#
# </div>

# %% [markdown]
# **1.** Escribe una función llamada calcular_precio() que reciba:
#
# El precio de un producto y un porcentaje de descuento.
#
# Si no se especifica el descuento, debe asumir un valor de 10%.
#
# La función debe regresar el precio final después del descuento.
#
# Prueba la función con un producto de $500 sin indicar el descuento.

# %%
# Respuesta
def calcular_precio (precio,porcentaje):
    precio = 500
    porcentaje = 0.10
    precio_final = precio + precio (porcentaje)
    return (precio_final)

# %%
calcular_precio = precio_final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 calcular_precio = precio_final
#
# NameError: name 'precio_final' is not defined

# %%
print(calcular_precio)
# Out:
# <function calcular_precio at 0x000002CE5663A340>

# %% [markdown]
# **2.**  Escribe una función llamada promedio() que pueda recibir cualquier cantidad de calificaciones usando *args.
#
# La función debe regresar el promedio de todas las calificaciones recibidas.
#
# Prueba la función con las calificaciones:
#
# 80, 90, 75, 95
#
# e imprime el resultado.

# %%
# Respuesta
def promedio (*args):
    prom_total = calificaciones / 4
    return prom_total

# %%
calificaciones = [80, 90, 75, 95]

# %% [markdown]
# ##### ========================================================================================
# ### Evaluación
# 1. Pregunta 1. Error: la variable precio se reasigna siempre a 500; asimismo, porcentaje se reasigna; la función se reasigna a una variable no declarada; errores de sintaxis. 2 puntos.
# 2. Pregunta 2. Error: no se utiliza la variable 'args' en el cálculo de calificaciones. 2 puntos
#
# Calificación final: 4 puntos
# ##### ========================================================================================

# %%
# Posible respuesta
def calcular_precio (precio, porcentaje = 0.1):
    return precio - precio * porcentaje
    
precio = float(input("Introduce precio:"))
ds = float(input("Introduce descuento:"))

print(calcular_precio(precio, ds))
# Out:
# Introduce precio: 800
# Introduce descuento: 0.2
# 640.0

# %%
# Posible respuesta
def promedio (*args):
    return sum(args) / len(args)

print(promedio(80, 90, 75, 95))
# Out:
# 85.0
