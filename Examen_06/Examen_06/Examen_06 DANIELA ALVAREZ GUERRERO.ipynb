# %% [markdown]
# <div style="background-color:#f2f2f2; border-left: 8px solid #2e8b57; padding: 20px; border-radius: 10px; font-family: Arial, sans-serif;">
#
# <center>
#
# <h1 style="color:#2e8b57;">Exámen 6: Cómputo científico con Python</h1>
# <h2 style="color:#2e8b57;">Instituto Mexicano del Petróleo</h2>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dra. Gabriela Berenice Díaz Cortés</strong><br>
# <em>gbdiaz@imp.mx</em>
# </p>
#
# <p style="font-size:16px; color:#333;">
# <strong>Dr. Luis Antonio López Peña</strong><br>
# <em>llopezp@imp.mx</em>
# </p>
#
# <p style="font-size:15px; color:#555;">
# Dirección de Investigación <br>
# Gerencia de Investigación en Explotación
# </p>
#
# <p style="font-size:15px; color:#444; margin-top: 20px;">
# <strong>Fecha de asignación:</strong> 9 de junio de 2026<br>
# <strong>Fecha de entrega:</strong> 9 de junio de 2026
# </p>
#
# </center>
#
# </div>

# %% [markdown]
# **1.** Define una clase, que se llame Estudiantes_Posgrado_IMP, con los siguientes atributos:
#
# nombre, apellidos, correo, nivel y status
#
# Se requiere que el atributo status tenga un valor por default de "Reprobado"
#
# Nota nivel se refiere a "Maestría" o "Doctorado"
#
# Crear un objeto que se llame estudiante, con tus datos personales.

# %%
class Estudiantes_Posgrado_IMP:
  def __init__(self,nombre,apellido,correo,nivel,status='Reprobado'):
   self.nombre=nombre
   self.apellido=apellido
   self.correo=correo
   self.nivel=nivel
   self.status=status

# %%
Estudiante=Estudiantes_Posgrado_IMP('Daniela','Alvarez Guerrero','posdalvarez@imp.mx','Maestria')
print("Nombre:", Estudiante.nombre)
print("Apellidos:", Estudiante.apellido)
print("Correo:", Estudiante.correo)
print("Nivel:", Estudiante.nivel)
print("Status:", Estudiante.status)
# Out:
# Nombre: Daniela
# Apellidos: Alvarez Guerrero
# Correo: posdalvarez@imp.mx
# Nivel: Maestria
# Status: Reprobado

# %% [markdown]
# **2.**  Crea un método que se llame resultado, dentro de la clase Estudiantes_Posgrado_IMP, que cambie el atributo status de reprobado a aprobado si la calificacion es mayor o igual a 8. Nota, calificacion seria un parámetro de entrada del método resultado.  Después de definir esta clase, crear un objeto estudiante y aplicar el método resultado considerando una calificación de 10. Imprimir el status final del objeto estudiante.

# %%
class Estudiantes_Posgrado_IMP:
   def __init__(self, nombre, apellidos, correo, nivel,calificacion,status="Reprobado"):
      self.nombre=nombre
      self.apellidos=apellidos
      self.correo=correo
      self.nivel=nivel
      self.calificacion =calificacion
      self.status=status

   def resultado(self, calificacion):
        if calificacion >= 8:
            self.status = "Aprobado"
        else:
            self.status = "Reprobado"

estudiante = Estudiantes_Posgrado_IMP("Daniela","Alvarez Guerrero","posdalvarez@imp.mx","Maestría",estudiante.resultado)
estudiante.resultado(10)

print("Status final:", estudiante.status)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      13         else:
#      14             self.status = "Reprobado"
# ---> 16 estudiante = Estudiantes_Posgrado_IMP("Daniela","Alvarez Guerrero","posdalvarez@imp.mx","Maestría",estudiante.resultado)
#      17 estudiante.resultado(10)
#      19 print("Status final:", estudiante.status)
#
# NameError: name 'estudiante' is not defined

# %% [markdown]
# ##### ========================================================================================
# ### Evaluación
# 1. Pregunta 1. Ok. 5 puntos
# 2. Pregunta 2. Ok. Casi, error de sintaxis, quizá un error al escribir. 4 puntos
#
# Calificación final: 9 puntos
# ##### ========================================================================================

# %%
# Corrección de error
class Estudiantes_Posgrado_IMP:
   def __init__(self, nombre, apellidos, correo, nivel,calificacion,status="Reprobado"):
      self.nombre=nombre
      self.apellidos=apellidos
      self.correo=correo
      self.nivel=nivel
      self.calificacion =calificacion
      self.status=status

   def resultado(self, calificacion):
        if calificacion >= 8:
            self.status = "Aprobado"
        else:
            self.status = "Reprobado"

estudiante = Estudiantes_Posgrado_IMP("Daniela","Alvarez Guerrero","posdalvarez@imp.mx","Maestría",7)
estudiante.resultado(10)

print("Status final:", estudiante.status)
# Out:
# Status final: Aprobado
